# %%
from openai import OpenAI

# %%
client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="API 키 연결 테스트입니다. '정상 연결' 이라고만 답해주세요."
)

# %%
print(response.output_text)
# Out:
# 정상 연결

# %%
print(response)
# Out:
# Response(id='resp_0f20d684a49952a9006aa37331324c87d0bb4dbbec3c7d03ad', created_at=1789096753.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-mini-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0f20d684a49952a9006aa37331981087d0a57f7f2e67b48f19', summary=[], type='reasoning', content=[], encrypted_content='gAAAAABqo3MyV3lnFHPT_0h5dFiy5cHX_8r6Yx-xnxR9P7d1S61500jECv9ujUhv47jJjy3KmAAwBc-1r3RseQ6u5I9p0HGrW_O0Vzq1dpXjOGL24WYipyhUwOmZVSpL14OoolT_GXkQtuNGPyN5A9AO0LDojjQ3_hLJvPbx0iQ4qsT-khDK6HrzdQKF_VDjDEWmgm-i0SOZI9_qPEqkt6r3_UKpHlRqAKsLzTAOsehz2XXrhYjbXAgIIaaTjexiGbbGEiR6ZnIFfbfMlIuXNYiybL_avlNxxpQl4YbAyuibLhJhWnm-w4hP9rMLKZlV53GvZHG4U02bxD_2IVPjLr0tUwmFSrIfXLJgRwYlYRtLpebjT4yfZvGhCDvrrW9NmNpuNCCmqgOeb90eiaC33XAYkFSjpSVmkiEBskdvI4E17-USChePkUTGGPYLd4E1pnTymnKsJwULgRBhUyiTURR4zbmQad9VbeKhjV8wOHAAp6rQ29ekXl1Beqohph9Mnfe6-pxLXAOkQIl-cZnWrTODqABnRtQ-QnGLl3XlGTbOQ9Zimisn0kyJL_7MUV1d-9LR_NAtHuARTPXI2hGuGrXcBgjnjOaOG6QqIKvD0VOoS6NAMVYTQxp8gjYOAWqvGqtTIw802vU9e1_KHHq15mu8fRWQ6-N1n8TzeBGGINMoX-9-LZXWlExrk_T8uZgrtb0qY1mYczZXsqP30AwPtGya9ZJIJ9Z-MTulib_foplano-RKHOYWKIpMAAT6CjD2jfsmgx37A2G1mD6JuZbsJtqai94Dc6EGcjvHmPcbRPvoIt3JmVcZ15qR0o6dpRcxcisnjvdpLPm_amddTrf73JEnSPaTrDh-rKIG6XHTv4eCzyL9u_dAH9mPpCMKN3fpnX8JVzo7qSSggbG2Fssss8oGjOrrp6UHioaum_tPyoQxuETiNy7KFZRLGZWbHrVJhqNE1033swEhGksFDJ15q4v1to9QKxr68sw1CPwK-UqtxWi1FNNl8ponZ8JL1pGg-23qWVet8MGx_mdEWE2kLPW_-Q7ilqk3v2wGMQE1sgcRYYTqExMkl-tUsyii61F1P_uwlHouG-WQ_fgbTkA2992Zs16Fj9WyvSBDeV4jWCNOoqTS_sfnLVvbEMJPhHX3bTPwlmNlQ5SndOrXsjjPHju089CJSUL-r56dR3pp98mTu2HvhWcxy9BCemi5VB1pxsR95FOCR8lP3UGwKynESReyD-8OHOrS4FbeCJ4cNPw7eswf14OojjuVEZZDMp9WIaXBhL0A3YmWXaIJC1AFVD-U68YjON-vdZuhDNASf7vJcXUWOkiL4iHf6vPVtaTLy8f9eBXtDuSwT5k0Gdf1KnL-QGllVvsACxObJhdoFyKV2-H7EsR4uWldNjr3ri6nfWQDqMx4YATps00C3PGwk1JQXpBRqBVvPtXfVUFiC_VUqHENicAQszNpt-L43nrEIXnPDEY7spzQunqbehbRZpS8hRmkq2efbtiyrhjn0cLLHzHlYXETpGZCP3QzCT_GH7jJ2510uyq347JLDsOWH1BaO47vrpgk-kriLtXvmav4-mAHKWTlxRRLsgHSCKTOOS7EhUWXYl58hjrxTEFKoefa37zfzDkdBiISRKPQvvvf5RHdOTZTEc=', status=None), ResponseOutputMessage(id='msg_0f20d684a49952a9006aa3733299fc87d0bb17dcc8f943213f', content=[ResponseOutputText(annotations=[], text='정상 연결', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, completed_at=1789096754.0, conversation=None, max_output_tokens=None, max_tool_calls=None, moderation=None, previous_response_id=None, prompt=None, prompt_cache_diagnostics=None, prompt_cache_key=None, prompt_cache_options=None, prompt_cache_retention='in_memory', reasoning=Reasoning(context='current_turn', effort='medium', generate_summary=None, mode='standard', summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=23, input_tokens_details=InputTokensDetails(cache_write_tokens=0, cached_tokens=0), output_tokens=81, output_tokens_details=OutputTokensDetails(reasoning_tokens=64), total_tokens=104), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True, tool_usage={'image_gen': {'input_tokens': 0, 'input_tokens_details': {'image_tokens': 0, 'text_tokens': 0}, 'output_tokens': 0, 'output_tokens_details': {'image_tokens': 0, 'text_tokens': 0}, 'total_tokens': 0}, 'web_search': {'num_requests': 0}})
