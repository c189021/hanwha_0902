# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\psj0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# ### batch() 함수로 일괄 처리하기
# - invoke : 동기(Synchronous) : [단일 입력 -> 단일 출력] : 응답의 청크를 스트리밍
# - stream : 동기(Synchronous) : [단일 입력 -> 데이터 스트림] : 입력에 대해 체인을 호출
# - batch : 동기(Synchronous) : [입력 목록 -> 출력 목록 (List)] : 입력 목록에 대해 체인을 호출

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOpenAI()

prompt = PromptTemplate.from_template("{topic} 에 대하여 3문장으로 설명해줘.")
# 프롬프트와 모델을 연결하여 대화 체인을 생성합니다.
chain = prompt | model | StrOutputParser()

# %%
chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic} 에 대하여 3문장으로 설명해줘.')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000002192508DA00>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000021925781C40>, root_client=<openai.OpenAI object at 0x000002192506E6F0>, root_async_client=<openai.AsyncOpenAI object at 0x0000021925A2EB10>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()

# %%
chain.batch([{"topic":"ChatGPT"}, {"topic":"Instagram"}])
# Out:
# Failed to get info from https://eu.api.langchain.com: LangSmithConnectionError('Connection error caused failure to GET /info in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError(\'HTTPSConnectionPool(host=\\\'eu.api.langchain.com\\\', port=443): Max retries exceeded with url: /info (Caused by NameResolutionError("HTTPSConnection(host=\\\'eu.api.langchain.com\\\', port=443): Failed to resolve \\\'eu.api.langchain.com\\\' ([Errno 11001] getaddrinfo failed)"))\'))\nContent-Length: None\nAPI Key: lsv2_********************************************ae')
# Run compression is not enabled. Please update to the latest version of LangSmith. Falling back to regular multipart ingestion.
# ['ChatGPT는 인공지능 챗봇으로 자연어 처리 기술을 활용하여 대화를 나눌 수 있는 서비스이다. 사용자의 질문에 대답하거나 채팅 상대로서 역할을 수행하여 다양한 주제에 대해 토론이 가능하다. 다양한 분야의 정보와 지식을 제공하며 상호작용을 통해 사용자와 소통한다.',
#  '인스타그램은 소셜 미디어 플랫폼으로, 사진과 동영상을 공유하고 이에 대한 좋아요나 댓글을 받을 수 있는 서비스이다. 사용자들은 팔로우를 통해 다양한 콘텐츠를 구독하고, 자신의 일상을 공유하며 소통할 수 있다. 또한 인스타그램 스토리와 라이브 기능을 통해 좀 더 다양한 활동을 할 수 있다.']

# %%
answer = chain.batch([{"topic":"ChatGPT"}, {"topic":"Instargram"}])
print(answer)
print(answer[0])
# Out:
# ['ChatGPT는 OpenAI에서 개발한 자연어 처리 기술을 이용한 대화형 인공지능이다. ChatGPT는 사용자의 질문이나 대화에 대해 자연스럽고 유창하게 응답할 수 있는 능력을 갖추고 있다. 현존하는 가장 발전된 대화형 인공지능 중 하나로, 다양한 분야에서 활용되고 있다.', 'Instagram은 사진과 동영상을 공유하는 소셜 미디어 플랫폼이다. 사용자들은 팔로우하고, 좋아요를 누르며 소통할 수 있다. 또한 해시태그를 활용하여 관심사나 주제별로 게시물을 찾을 수 있다.']
# ChatGPT는 OpenAI에서 개발한 자연어 처리 기술을 이용한 대화형 인공지능이다. ChatGPT는 사용자의 질문이나 대화에 대해 자연스럽고 유창하게 응답할 수 있는 능력을 갖추고 있다. 현존하는 가장 발전된 대화형 인공지능 중 하나로, 다양한 분야에서 활용되고 있다.

# %%
# "max_concurrency": 3 동시에 세개씩 처리함.
chain.batch(
    [
        {"topic": "ChatGPT"},
        {"topic": "Instagram"},
        {"topic": "멀티모달"},
        {"topic": "프로그래밍"},
        {"topic": "머신러닝"},
    ],
    config={"max_concurrency": 3},
)
# Out:
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 16825
# API Key: lsv2_********************************************aetrace=01a09f1b-a4c9-7c10-a30b-70df51066591,id=01a09f1b-a4c9-7c10-a30b-70df51066591; trace=01a09f1b-a4c9-7c10-a30b-70df51066591,id=01a09f1b-a4f5-7ff0-8126-8f0cfd741545; trace=01a09f1b-a4c9-7c10-a30b-70df51066591,id=01a09f1b-a531-7a73-83f6-4d0a29e78f90; trace=01a09f1b-a4f4-7462-b12e-472c2a0d7dc8,id=01a09f1b-a4f4-7462-b12e-472c2a0d7dc8; trace=01a09f1b-a4f4-7462-b12e-472c2a0d7dc8,id=01a09f1b-a4f6-7aa3-b0f5-e2b86387e39b; trace=01a09f1b-a4f4-7462-b12e-472c2a0d7dc8,id=01a09f1b-a532-7ba0-bc6d-fba02ea4a09a
# ['ChatGPT는 자연어 처리 기술을 사용하여 대화형 인공지능 채팅을 제공하는 플랫폼이다. 사용자들은 다양한 주제에 관한 질문을 하거나 대화를 나눌 수 있으며, 자연스럽고 유익한 상호작용을 경험할 수 있다. ChatGPT는 일상적인 대화에서부터 전문적인 지식까지 다양한 콘텐츠를 다루며, 학습과 정보 제공을 돕는다.',
#  '인스타그램은 사진과 동영상을 공유하는 소셜 미디어 플랫폼이며, 사용자들은 팔로워들과 소통하고 콘텐츠를 공유한다. 해시태그를 통해 관심사에 맞는 게시물을 검색하고 탐색할 수 있어 인기 있는 SNS 중 하나이다. 현재 많은 유명인과 브랜드가 활발하게 활동하고 있어 광범위한 사용자층을 보유하고 있다.',
#  '멀티모달은 여러 가지 형태의 매체를 사용하여 정보를 전달하거나 상호작용하는 방법을 의미합니다. 이는 텍스트, 이미지, 음성, 동영상 등 다양한 매체를 융합하여 효과적인 소통과 상호작용을 이끌어냅니다. 멀티모달 접근법을 통해 정보를 다양한 감각으로 받아들이고 처리할 수 있어, 사용자들에게 보다 풍부하고 효과적인 경험을 제공할 수 있습니다.',
#  '프로그래밍은 컴퓨터에게 작업을 수행하도록 지시하는 일련의 명령을 작성하는 과정입니다. 이러한 명령은 프로그래밍 언어로 표현되며, 컴퓨터는 이를 해석하여 원하는 결과를 출력합니다. 프로그래밍을 통해 문제 해결이나 새로운 소프트웨어 및 애플리케이션을 개발할 수 있습니다.',
#  '머신러닝은 컴퓨터가 데이터를 학습하고 패턴을 발견하여 예측하거나 의사결정을 내리는 인공지능 기술이다. 머신러닝은 규칙이나 프로그래밍 없이 스스로 학습하며 성능을 개선할 수 있다. 이를 통해 다양한 분야에서 데이터 분석, 이미지 인식, 자연어 처리 등 다양한 문제를 해결할 수 있다.']

# %%
async for token in chain.astream({"topic": "YouTube"}):
    # 메시지 내용을 출력합니다. 줄바꿈 없이 바로 출력하고 버퍼를 비웁니다.
    print(token, end="", flush=True)
# Out:
# YouTube는 세계 최대의 동영상 공유 플랫폼으로, 수많은 영상 콘텐츠를 무료로 시청할 수 있는 서비스이다. 유저들은 자신의 채널을 만들어 동영상을 업로드하고 다른 사람들과 소통하며, 수익을 창출할 수도 있다. 다양한 콘텐츠를 제공하고 있는 YouTube는 인기 있는 엔터테인먼트 플랫폼으로 성장하고 있다.
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length:
01a09f1b-a4f4-7462-b12e-472c2a0d7dc8,id=01a09f1b-a4f4-7462-b12e-472c2a0d7dc8

# %%
# 비동기 체인 객체의 'ainvoke' 메서드를 호출하여 'NVDA' 토픽을 처리합니다.
my_process = chain.ainvoke({"topic": "NVDA"})

# %%
# 비동기로 처리되는 프로세스가 완료될 때까지 기다립니다.
await my_process
# Out:
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 58190
# API Key: lsv2_********************************************aetrace=01a09f1b-cd4f-7871-9282-b083f4cfa3f5,id=01a09f1b-e469-71c1-9f55-288535f0b33f; trace=01a09f1b-cd50-7f52-bcc1-82152af71671,id=01a09f1b-e46a-7473-9f72-e9fcdfc66843; trace=01a09f1b-cd50-7f52-bcc1-8225c5619e8a,id=01a09f1b-e46b-7643-8699-a2969642882c; trace=01a09f1b-cd50-7f52-bcc1-8235fcf2caa0,id=01a09f1b-e46b-7643-8699-a2a0b8ecc1f1; trace=01a09f1b-cd50-7f52-bcc1-824ac173d29a,id=01a09f1b-e46c-7cb0-a15a-e949f5b6f67e; trace=01a09f1b-e644-7501-a72e-513a60da76d2,id=01a09f1b-e644-7501-a72e-513a60da76d2; trace=01a09f1b-e644-7501-a72e-513a60da76d2,id=01a09f1b-e645-7962-a1a3-9c6a0454235e; trace=01a09f1b-e644-7501-a72e-513a60da76d2,id=01a09f1b-e648-7202-b84f-5fa434891027; trace=01a09f1b-e644-7501-a72e-513a60da76d2,id=01a09f1b-ee08-70c2-ba58-79921d2a5b35; trace=01a09f1b-cd4f-7871-9282-b083f4cfa3f5,id=01a09f1b-cd4f-7871-9282-b083f4cfa3f5; trace=01a09f1b-cd50-7f52-bcc1-82152af71671,id=01a09f1b-cd50-7f52-bcc1-82152af71671; trace=01a09f1b-cd50-7f52-bcc1-8225c5619e8a,id=01a09f1b-cd50-7f52-bcc1-8225c5619e8a; trace=01a09f1b-cd50-7f52-bcc1-8225c5619e8a,id=01a09f1b-cd5b-71d0-ba07-cd296b00a614; trace=01a09f1b-cd50-7f52-bcc1-8235fcf2caa0,id=01a09f1b-cd50-7f52-bcc1-8235fcf2caa0; trace=01a09f1b-cd50-7f52-bcc1-8235fcf2caa0,id=01a09f1b-d7d2-76d3-9cfd-dc9ac91a2f8b; trace=01a09f1b-cd50-7f52-bcc1-824ac173d29a,id=01a09f1b-cd50-7f52-bcc1-824ac173d29a; trace=01a09f1b-cd50-7f52-bcc1-824ac173d29a,id=01a09f1b-d83d-7431-b76b-81099128e5a7
# 'NVDA는 NVIDIA사가 만든 그래픽 처리 장치 및 시스템을 제조하는 회사이다. 현재 세계적으로 그래픽 처리율 및 성능 면에서 선두를 달리고 있다. 주로 게임 산업 및 인공지능 분야에서 활용되고 있다.'
