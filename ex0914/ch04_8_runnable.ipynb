# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\psj0902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Runnable로 병렬 체인 구성
# - chain이 두개이상

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

# %%
model = ChatOpenAI()

# %%
# {country} 의 수도를 물어보는 체인을 생성합니다.
chain1 = (
    PromptTemplate.from_template("{country} 의 수도는 어디야?")
    | model
    | StrOutputParser()
)

# {country} 의 면적을 물어보는 체인을 생성합니다.
chain2 = (
    PromptTemplate.from_template("{country} 의 면적은 얼마야?")
    | model
    | StrOutputParser()
)
print(chain1)
print(chain2)
# Out:
# first=PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country} 의 수도는 어디야?') middle=[ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001F4A1D69AC0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F4A1D091C0>, root_client=<openai.OpenAI object at 0x000001F4A131E510>, root_async_client=<openai.AsyncOpenAI object at 0x000001F4A16A61B0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)] last=StrOutputParser()
# first=PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country} 의 면적은 얼마야?') middle=[ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001F4A1D69AC0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F4A1D091C0>, root_client=<openai.OpenAI object at 0x000001F4A131E510>, root_async_client=<openai.AsyncOpenAI object at 0x000001F4A16A61B0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)] last=StrOutputParser()

# %%
combined = RunnableParallel(capital=chain1, area=chain2)
print(combined)

# 반환되는 결과 객체의 모양
# {
#     "capital": chain1의_실행_결과,
#     "area": chain2의_실행_결과
# }

# 결과 예시
# {
#     "capital": "서울",
#     "area": "100,210 km²"
# }
# Out:
# steps__={'capital': PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country} 의 수도는 어디야?')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001F4A1D69AC0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F4A1D091C0>, root_client=<openai.OpenAI object at 0x000001F4A131E510>, root_async_client=<openai.AsyncOpenAI object at 0x000001F4A16A61B0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser(), 'area': PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country} 의 면적은 얼마야?')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001F4A1D69AC0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F4A1D091C0>, root_client=<openai.OpenAI object at 0x000001F4A131E510>, root_async_client=<openai.AsyncOpenAI object at 0x000001F4A16A61B0>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()}

# %%
c1 = chain1.invoke({"country": "대한민국"})

c2 = chain2.invoke({"country": "미국"})

c3 = combined.invoke({"country": "대한민국"})

print(c1)
print(c2)
print(c3)
# Out:
# Failed to get info from https://eu.api.langchain.com: LangSmithConnectionError('Connection error caused failure to GET /info in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError(\'HTTPSConnectionPool(host=\\\'eu.api.langchain.com\\\', port=443): Max retries exceeded with url: /info (Caused by NameResolutionError("HTTPSConnection(host=\\\'eu.api.langchain.com\\\', port=443): Failed to resolve \\\'eu.api.langchain.com\\\' ([Errno 11001] getaddrinfo failed)"))\'))\nContent-Length: None\nAPI Key: lsv2_********************************************ae')
# Run compression is not enabled. Please update to the latest version of LangSmith. Falling back to regular multipart ingestion.
# 대한민국의 수도는 서울이다.
# 미국의 면적은 약 9,833,520 km² 입니다.
# {'capital': '대한민국의 수도는 서울이야.', 'area': '대한민국의 총 면적은 약 100,363.49 km² 입니다.'}

# %%
b1 = chain1.batch([{"country": "대한민국"}, {"country": "미국"}])

b2 = chain2.batch([{"country": "대한민국"}, {"country": "미국"}])

b3 = combined.batch([{"country": "대한민국"}, {"country": "미국"}])

print(b1)
print(b2)
print(b3)
# Out:
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 19081
# API Key: lsv2_********************************************aetrace=01a09f1e-b53f-75b2-91d1-39fdf8565769,id=01a09f1e-b53f-75b2-91d1-39fdf8565769; trace=01a09f1e-b53f-75b2-91d1-39fdf8565769,id=01a09f1e-b57c-7d42-a1bd-284217d462de; trace=01a09f1e-b53f-75b2-91d1-39fdf8565769,id=01a09f1e-b5b3-7220-8318-d8bd9cf3edf8; trace=01a09f1e-b53f-75b2-91d1-39fdf8565769,id=01a09f1e-c00e-74c0-a438-87527c73f357; trace=01a09f1e-c00f-79b1-b440-1904556c7ff5,id=01a09f1e-c00f-79b1-b440-1904556c7ff5; trace=01a09f1e-c00f-79b1-b440-1904556c7ff5,id=01a09f1e-c00f-79b1-b440-19170492b5c0; trace=01a09f1e-c00f-79b1-b440-1904556c7ff5,id=01a09f1e-c010-7621-8da5-390422fdcbb0
# ['대한민국의 수도는 서울이야.', '미국의 수도는 워싱턴 D.C.입니다.']
# ['대한민국의 총 면적은 약 100,363km² 입니다.', '미국의 면적은 약 983 만제곱 킬로미터입니다.']
# [{'capital': '대한민국의 수도는 서울입니다.', 'area': '대한민국의 총 면적은 100,363㎢이다.'}, {'capital': '미국의 수도는 워싱턴 D.C.입니다.', 'area': '미국의 면적은 9,833,520 km² 입니다.'}]
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 76351
# API Key: lsv2_********************************************aetrace=01a09f1e-c00f-79b1-b440-1904556c7ff5,id=01a09f1e-c684-7ff2-9d94-eddc735d5af8; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c686-7f33-8a43-87334df15dee; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c687-7671-a42b-579808622240; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c688-7fb2-9307-039acdd3bfe9; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c689-7050-b43e-dfb93326b60d; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-cd23-7f72-8bfc-ca9d77cf8e9e; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c68d-77f3-bd57-14f6da3958ab; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c68e-75c1-9c52-3ffb89780c23; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-c68f-7182-a624-1d3743b335d3; trace=01a09f1e-c686-7f33-8a43-87334df15dee,id=01a09f1e-cd87-7280-9f52-30dc14cb82df; trace=01a09f1e-d3ec-7c30-a134-eb0bd543a8bb,id=01a09f1e-d3ec-7c30-a134-eb0bd543a8bb; trace=01a09f1e-d3ec-7c30-a134-eb0bd543a8bb,id=01a09f1e-d3ed-73f2-a0ff-4af3a286a98f; trace=01a09f1e-d3ec-7c30-a134-eb0bd543a8bb,id=01a09f1e-d3f1-7771-9cc6-98d3393afcd7; trace=01a09f1e-d3ec-7c30-a134-eb0bd543a8bb,id=01a09f1e-dd1b-7f12-b9a4-67711a2b26f4; trace=01a09f1e-d3ec-7c30-a134-eb1652a10211,id=01a09f1e-d3ec-7c30-a134-eb1652a10211; trace=01a09f1e-d3ec-7c30-a134-eb1652a10211,id=01a09f1e-d3ee-7670-9f40-34b5f72172bc; trace=01a09f1e-d3ec-7c30-a134-eb1652a10211,id=01a09f1e-d3f7-7910-b783-39bb8b1a5c1d; trace=01a09f1e-d3ec-7c30-a134-eb1652a10211,id=01a09f1e-dd1d-7933-bd2f-5abbdc882e33; trace=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6,id=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6; trace=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6,id=01a09f1e-dd22-7333-936b-a258ff17570a; trace=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6,id=01a09f1e-dd25-70e0-8da7-213db29376fb; trace=01a09f1e-dd21-7e11-8aa3-333dc7a15830,id=01a09f1e-dd21-7e11-8aa3-333dc7a15830; trace=01a09f1e-dd21-7e11-8aa3-333dc7a15830,id=01a09f1e-dd24-72f1-9a8e-72401c1d2857; trace=01a09f1e-dd21-7e11-8aa3-333dc7a15830,id=01a09f1e-dd28-7f83-87be-afb1d96aa940; trace=01a09f1e-c00f-79b1-b440-1904556c7ff5,id=01a09f1e-c00f-79b1-b440-1904556c7ff5; trace=01a09f1e-c00f-79b1-b440-1904556c7ff5,id=01a09f1e-c010-7621-8da5-390422fdcbb0

# %% [markdown]
# ### 값을 전달해주는 RunnablePassthrough

# %%
from langchain_core.runnables import RunnablePassthrough

# prompt 와 llm 을 생성합니다.
prompt = PromptTemplate.from_template("{num} 의 10배는?")
llm = ChatOpenAI(temperature=0)

# chain 을 생성합니다.
chain = prompt | llm
print(chain)
# Out:
# first=PromptTemplate(input_variables=['num'], input_types={}, partial_variables={}, template='{num} 의 10배는?') middle=[] last=ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001F4B827A870>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001F4B83305F0>, root_client=<openai.OpenAI object at 0x000001F4B82EFEC0>, root_async_client=<openai.AsyncOpenAI object at 0x000001F4B827B710>, temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
chain.invoke({"num": 5})
# Out:
# AIMessage(content='50입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 16, 'total_tokens': 19, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwjNb94vKFZqWgu8ZGC2hWYvpnhl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09f1f-24a0-7e42-a9c3-cf3eef6e9cdf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 3, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 67702
# API Key: lsv2_********************************************aetrace=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6,id=01a09f1e-e529-7a20-8c8b-7dc2f2ecc9da; trace=01a09f1e-dd21-7e11-8aa3-333dc7a15830,id=01a09f1e-e52a-73c2-baa2-da76faf96747; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e52d-7e30-a61c-8c8652428011; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e52e-7972-a7c0-74b7d67368e6; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e52e-7972-a7c0-74c6ee062b3c; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e87b-7ac1-98ad-7fe396935b74; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e530-7732-a126-2c072d42ea86; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e530-7732-a126-2c1986b2f23c; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-e531-7843-878f-33f303c36f81; trace=01a09f1e-e52c-7fd2-b6e9-0cfa3395ab32,id=01a09f1e-eddd-7781-b8fb-dd21d76b2214; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e52d-7e30-a61c-8c726e4bfe27; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e534-7f90-a4b0-bcfe97b51b88; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e534-7f90-a4b0-bd080b08b056; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e535-7651-a041-93dc2cfb0cf5; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-ec9f-73a2-8f23-f5552e16e056; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e537-7e12-94cb-5194c68172a7; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e537-7e12-94cb-51a149c741b6; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-e537-7e12-94cb-51bec89163da; trace=01a09f1e-e52d-7e30-a61c-8c726e4bfe27,id=01a09f1e-ec7e-7b53-b025-edca039f17d3; trace=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6,id=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6; trace=01a09f1e-dd20-7b21-93f8-4bb5a82d09b6,id=01a09f1e-dd25-70e0-8da7-213db29376fb; trace=01a09f1e-dd21-7e11-8aa3-333dc7a15830,id=01a09f1e-dd21-7e11-8aa3-333dc7a15830

# %%
chain.invoke(5)
# Out:
# AIMessage(content='50입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 16, 'total_tokens': 19, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwjSLO7ZUjycNh75VAbZHYwCOFsb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09f1f-355a-7f42-b7c1-363be0dc5758-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 3, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
RunnablePassthrough().invoke({"num": 10})
# Out:
# {'num': 10}
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 9974
# API Key: lsv2_********************************************aetrace=01a09f1f-249c-7a41-89c5-7a4892ccc0f8,id=01a09f1f-249c-7a41-89c5-7a4892ccc0f8; trace=01a09f1f-249c-7a41-89c5-7a4892ccc0f8,id=01a09f1f-249d-7de1-91f4-81966a35a2f5; trace=01a09f1f-249c-7a41-89c5-7a4892ccc0f8,id=01a09f1f-24a0-7e42-a9c3-cf3eef6e9cdf

# %%
num1 = chain.invoke({"num": 5})

num2 = chain.invoke(5)

num3 = RunnablePassthrough().invoke({"num": 10})

print(num1)
print(num2)
print(num3)
# Out:
# content='50' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1, 'prompt_tokens': 16, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwjaZx6Y5tjUn3sP0NMwRbNA3Qld', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a09f1f-5566-7472-bd30-b3a9e67619a8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 1, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='50' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1, 'prompt_tokens': 16, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwjbVd1CWmdhreA5DWP3AsCPZqzP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a09f1f-5a1c-7940-bdbd-8cc5af18507b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 1, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# {'num': 10}

# %%
runnable_chain = {"num": RunnablePassthrough()} | prompt | ChatOpenAI()

# dict 값이 RunnablePassthrough() 로 변경되었습니다.
runnable_chain.invoke(10)
# Out:
# AIMessage(content='10의 10배는 100입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 16, 'total_tokens': 27, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwjlChnCJt1QMQGKRLw4gejUc0r4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09f1f-80f8-7562-9807-87952225ab47-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 11, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
RunnablePassthrough().invoke({"num": 1})
# Out:
# {'num': 1}
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 21653
# API Key: lsv2_********************************************aetrace=01a09f1f-5565-7d13-8c89-0207995e773b,id=01a09f1f-5565-7d13-8c89-0207995e773b; trace=01a09f1f-5565-7d13-8c89-0207995e773b,id=01a09f1f-5565-7d13-8c89-021447da6bb6; trace=01a09f1f-5565-7d13-8c89-0207995e773b,id=01a09f1f-5566-7472-bd30-b3a9e67619a8; trace=01a09f1f-5a1b-7e62-bb60-0046f75e7c53,id=01a09f1f-5a1b-7e62-bb60-0046f75e7c53; trace=01a09f1f-5a1b-7e62-bb60-0046f75e7c53,id=01a09f1f-5a1c-7940-bdbd-8cbe8c5e730b; trace=01a09f1f-5a1b-7e62-bb60-0046f75e7c53,id=01a09f1f-5a1c-7940-bdbd-8cc5af18507b; trace=01a09f1f-5db5-7792-b980-be34b76834f9,id=01a09f1f-5db5-7792-b980-be34b76834f9

# %%
# 입력 키: num, 할당(assign) 키: new_num
(RunnablePassthrough.assign(new_num=lambda x: x["num"] * 3)).invoke({"num": 1})
# Out:
# {'num': 1, 'new_num': 3}
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 15691
# API Key: lsv2_********************************************aetrace=01a09f1f-80f6-7eb1-9364-2e958e570627,id=01a09f1f-80f6-7eb1-9364-2e958e570627; trace=01a09f1f-80f6-7eb1-9364-2e958e570627,id=01a09f1f-80f6-7eb1-9364-2eab356e0520; trace=01a09f1f-80f6-7eb1-9364-2e958e570627,id=01a09f1f-80f7-7ef1-93cd-b87dc8b3f978; trace=01a09f1f-80f6-7eb1-9364-2e958e570627,id=01a09f1f-80f8-7562-9807-878668ebf6ec; trace=01a09f1f-80f6-7eb1-9364-2e958e570627,id=01a09f1f-80f8-7562-9807-87952225ab47; trace=01a09f1f-9161-7bf3-874c-fb671fe3151f,id=01a09f1f-9161-7bf3-874c-fb671fe3151f

# %% [markdown]
# ### 병렬로 Runable을 실행하는 RunnableParallel

# %%
from langchain_core.runnables import RunnableParallel

# RunnableParallel 인스턴스를 생성합니다. 이 인스턴스는 여러 Runnable 인스턴스를 병렬로 실행할 수 있습니다.
runnable = RunnableParallel(
    # RunnablePassthrough 인스턴스를 'passed' 키워드 인자로 전달합니다. 이는 입력된 데이터를 그대로 통과시키는 역할을 합니다.
    passed=RunnablePassthrough(),
    # 'extra' 키워드 인자로 RunnablePassthrough.assign을 사용하여, 'mult' 람다 함수를 할당합니다. 이 함수는 입력된 딕셔너리의 'num' 키에 해당하는 값을 3배로 증가시킵니다.
    extra=RunnablePassthrough.assign(mult=lambda x: x["num"] * 3),
    # 'modified' 키워드 인자로 람다 함수를 전달합니다. 이 함수는 입력된 딕셔너리의 'num' 키에 해당하는 값에 1을 더합니다.
    modified=lambda x: x["num"] + 1,
)

# runnable 인스턴스에 {'num': 1} 딕셔너리를 입력으로 전달하여 invoke 메소드를 호출합니다.
runnable.invoke({"num": 1})
# Out:
# {'passed': {'num': 1}, 'extra': {'num': 1, 'mult': 3}, 'modified': 2}
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 5748
# API Key: lsv2_********************************************aetrace=01a09f1f-a175-7202-9c37-a461ee6c96fe,id=01a09f1f-a175-7202-9c37-a461ee6c96fe; trace=01a09f1f-a175-7202-9c37-a461ee6c96fe,id=01a09f1f-a175-7202-9c37-a47cb56c4a4b; trace=01a09f1f-a175-7202-9c37-a461ee6c96fe,id=01a09f1f-a176-7542-a6a6-6f4cc162cf0f

# %%
chain1 = (
    {"country": RunnablePassthrough()}
    | PromptTemplate.from_template("{country} 의 수도는?")
    | ChatOpenAI()
)
chain2 = (
    {"country": RunnablePassthrough()}
    | PromptTemplate.from_template("{country} 의 면적은?")
    | ChatOpenAI()
)

# %%
combined_chain = RunnableParallel(capital=chain1, area=chain2)
combined_chain.invoke("대한민국")
# Out:
# {'capital': AIMessage(content='서울특별시 입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 19, 'total_tokens': 30, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwkDuokfbmHV0qOA6sy5mDdJrVj9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09f1f-efd8-7503-afb3-b028c7ea57c5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 11, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  'area': AIMessage(content='대한민국의 면적은 약 100,363.6 제곱 킬로미터입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 20, 'total_tokens': 49, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwkDWFRipsuJ592ydvhi1O399CGd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09f1f-efe1-7df2-b941-ed0f1b1b21a8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 29, 'total_tokens': 49, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 11692
# API Key: lsv2_********************************************aetrace=01a09f1f-d362-76b1-afb1-1c443602048f,id=01a09f1f-d362-76b1-afb1-1c443602048f; trace=01a09f1f-d362-76b1-afb1-1c443602048f,id=01a09f1f-d363-75d1-9ea5-065b0a26de17; trace=01a09f1f-d362-76b1-afb1-1c443602048f,id=01a09f1f-d364-7d73-9c55-aceef3d904f6; trace=01a09f1f-d362-76b1-afb1-1c443602048f,id=01a09f1f-d364-7d73-9c55-acfafbcdf547; trace=01a09f1f-d362-76b1-afb1-1c443602048f,id=01a09f1f-d365-79f2-950f-c8cae0c3173a; trace=01a09f1f-d362-76b1-afb1-1c443602048f,id=01a09f1f-d364-7d73-9c55-ad0fa6932bf1

# %% [markdown]
# ### 함수를 실행하는 RunableLambda

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from datetime import datetime


def get_today(a):
    # 오늘 날짜를 가져오기
    return datetime.today().strftime("%b-%d")


# 오늘 날짜를 출력
get_today(None)
# Out:
# 'Sep-14'
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 32569
# API Key: lsv2_********************************************aetrace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efcf-7fa0-97f7-098b75e54220; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efd0-7441-a5d4-8f592fdc4135; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efd1-7a82-98f7-8098c803c2d0; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efd2-77e0-bf74-d50acb61f62d; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efd5-7162-8fab-d990727a0cd5; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efd8-7503-afb3-b028c7ea57c5; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efd9-7011-a0e9-337dbd7bc152; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efda-76e2-8fca-d1ba80eeb827; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efdd-7f82-9bb4-279a04fad1d7; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efdf-7ff1-b5c3-2f7cfb0fa2cb; trace=01a09f1f-efcf-7fa0-97f7-098b75e54220,id=01a09f1f-efe1-7df2-b941-ed0f1b1b21a8

# %%
from langchain_core.runnables import RunnableLambda, RunnablePassthrough

# prompt 와 llm 을 생성합니다.
prompt = PromptTemplate.from_template(
    "{today} 가 생일인 유명인이나 가수 {n} 명을 나열하세요. 생년월일을 표기해 주세요."
)
llm = ChatOpenAI(temperature=0, model_name="gpt-4o-mini")

# chain 을 생성합니다.
chain = (
    {"today": RunnableLambda(get_today), "n": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# 오늘(9/14) 생일인 유명인 3명 출력
print(chain.invoke(3))
# Out:
# 9월 14일에 생일인 유명인이나 가수는 다음과 같습니다:
#
# 1. **안젤리나 졸리 (Angelina Jolie)** - 1975년 9월 14일
# 2. **매리 제이 블라이즈 (Mary J. Blige)** - 1971년 9월 14일
# 3. **니콜라스 케이지 (Nicolas Cage)** - 1964년 9월 14일
#
# 이 외에도 많은 유명인들이 이 날에 태어났습니다!

# %%
from operator import itemgetter

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda
from langchain_openai import ChatOpenAI


# 문장의 길이를 반환하는 함수입니다.
def length_function(text):
    return len(text)


# 두 문장의 길이를 곱한 값을 반환하는 함수입니다.
def _multiple_length_function(text1, text2):
    return len(text1) * len(text2)


# _multiple_length_function 함수를 사용하여 두 문장의 길이를 곱한 값을 반환하는 함수입니다.
def multiple_length_function(_dict):
    return _multiple_length_function(_dict["text1"], _dict["text2"])


prompt = ChatPromptTemplate.from_template("{a} + {b} 는 무엇인가요?")
model = ChatOpenAI()

chain1 = prompt | model

chain = (
    {
        "a": itemgetter("word1") | RunnableLambda(length_function),
        "b": {"text1": itemgetter("word1"), "text2": itemgetter("word2")}
        | RunnableLambda(multiple_length_function),
    }
    | prompt
    | model
)
# Out:
# Failed to multipart ingest runs: Connection error caused failure to POST https://eu.api.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'eu.api.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'eu.api.langchain.com\', port=443): Failed to resolve \'eu.api.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 13186
# API Key: lsv2_********************************************aetrace=01a09f20-41d3-7220-adec-a2dae71363b2,id=01a09f20-41d3-7220-adec-a2dae71363b2; trace=01a09f20-41d3-7220-adec-a2dae71363b2,id=01a09f20-41d4-7f81-a7c8-8c64c52220cb; trace=01a09f20-41d3-7220-adec-a2dae71363b2,id=01a09f20-41d5-7b72-b543-ad67f56b80ac; trace=01a09f20-41d3-7220-adec-a2dae71363b2,id=01a09f20-41d7-7412-b972-ae33dbbdfe1c; trace=01a09f20-41d3-7220-adec-a2dae71363b2,id=01a09f20-41da-7941-87a5-5749b9aa893c; trace=01a09f20-41d3-7220-adec-a2dae71363b2,id=01a09f20-41db-7ce1-b243-16858f3585bf

# %%
chain.invoke({"word1": "hello", "word2": "world"})
# Out:
# AIMessage(content='5 + 25 = 30', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 22, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-ENwkly8j5Au4I38ubwUbXBY6Kw3p1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a09f20-7441-7cb3-9053-139d1072d7d5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 7, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
