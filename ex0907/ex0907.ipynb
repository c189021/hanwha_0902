# %%
# 모듈 import
from datetime import datetime
from pydantic import BaseModel, PositiveInt, ValidationError
from typing import Annotated, Literal
from annotated_types import Gt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 모듈 import
#       2 from datetime import datetime
# ----> 3 from pydantic import BaseModel, PositiveInt, ValidationError
#       4 from typing import Annotated, Literal
#       5 from annotated_types import Gt
#
# File d:\psj0902\hanwha_0902\ex0907\pydantic.py:6
#       1 """
#       2 Pydantic 예시 코드 모음
#       3 실행: pip install pydantic  (설치 후) -> python pydantic.py
#       4 """
# ----> 6 from pydantic import BaseModel, ValidationError, field_validator
#       9 # ----------------------------------------------------------------------
#      10 # 예시 1. 기본 모델 정의 및 자동 타입 변환
#      11 # ----------------------------------------------------------------------
#      12 def example_1_basic_model():
#
# ImportError: cannot import name 'BaseModel' from partially initialized module 'pydantic' (most likely due to a circular import) (d:\psj0902\hanwha_0902\ex0907\pydantic.py)

# %%
# 클래스 선언부
class User(BaseModel):
    id: int
    name: str = 'John Doe'
    signup_ts: datetime | None = None   # = None 을 줘야 생략 가능한 필드가 됩니다
    tastes: dict[str, PositiveInt]

# %%
# 데이터
external_data = {
    'id': 123,
    'signup_ts': '2019-06-01 12:22',
    'tastes': {
        'wine': 9,
        b'cheese': 7,
        'cabbage': '1',
    },
}

# %%
# user 오브젝트 생성 (사용하기 전에 반드시 먼저 생성)
user = User(**external_data)

# %%
print(user.id)
#> 123

print(user.model_dump())
#> {
#>   'id': 123,
#>   'name': 'John Doe',
#>   'signup_ts': datetime.datetime(2019, 6, 1, 12, 22),
#>   'tastes': {'wine': 9, 'cheese': 7, 'cabbage': 1},
#> }
# Out:
# 123
# {'id': 123, 'name': 'John Doe', 'signup_ts': datetime.datetime(2019, 6, 1, 12, 22), 'tastes': {'wine': 9, 'cheese': 7, 'cabbage': 1}}

# %%
print(user.signup_ts)
print(user.tastes)
# Out:
# 2019-06-01 12:22:00
# {'wine': 9, 'cheese': 7, 'cabbage': 1}

# %%
# 검증 실패(ValidationError) 확인
external_data2 = {
    'id': 'not an int',
    'tastes': {},
}

# %%
try:
    User(**external_data2)
except ValidationError as e:
    print(e.errors())
# Out:
# [{'type': 'int_parsing', 'loc': ('id',), 'msg': 'Input should be a valid integer, unable to parse string as an integer', 'input': 'not an int', 'url': 'https://errors.pydantic.dev/2.13/v/int_parsing'}]

# %%
# Fruit 모델 - Literal, Annotated 사용
class Fruit(BaseModel):
    name: str
    color: Literal['red', 'green']
    weight: Annotated[float, Gt(0)]
    bazam: dict[str, list[tuple[int, bool, float]]]

# %%
print(
    Fruit(
        name='Apple',
        color='red',
        weight=4.2,
        bazam={'foobar': [(1, True, 0.1)]},
    )
)
# Out:
# name='Apple' color='red' weight=4.2 bazam={'foobar': [(1, True, 0.1)]}

# %%
# Meeting 모델 - model_dump 옵션들
class Meeting(BaseModel):
    when: datetime
    where: bytes
    why: str = 'No idea'

# %%
m = Meeting(when='2020-01-01T12:00', where='home')

# %%
print(m.model_dump(exclude_unset=True))
#> {'when': datetime.datetime(2020, 1, 1, 12, 0), 'where': b'home'}
# Out:
# {'when': datetime.datetime(2020, 1, 1, 12, 0), 'where': b'home'}

# %%
print(m.model_dump(exclude={'where'}, mode='json'))
#> {'when': '2020-01-01T12:00:00', 'why': 'No idea'}
# Out:
# {'when': '2020-01-01T12:00:00', 'why': 'No idea'}

# %%
print(m.model_dump_json(exclude_defaults=True))
#> {"when":"2020-01-01T12:00:00","where":"home"}
# Out:
# {"when":"2020-01-01T12:00:00","where":"home"}
